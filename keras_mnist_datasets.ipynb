# %%
import cv2
from pylab import *
from skimage import io
import numpy
import os
randomByteArray=bytearray(os.urandom(120000))
flatNumpyArray=numpy.array(randomByteArray)
print(flatNumpyArray)
grayImage=flatNumpyArray.reshape(300,400)

bgrImage=flatNumpyArray.reshape(100,400,3)
figure(0)
io.imshow(grayImage)
figure(1)
io.imshow(bgrImage)
# Out:
# [140 141  79 ... 136 233  84]

# %%
import matplotlib
import numpy
import matplotlib.pyplot as plt
import matplotlib.pyplot as MPL
import numpy as np
from keras.datasets import mnist
from keras import models
from keras.utils import to_categorical
from keras import layers
(train_images,train_labels),(test_images,test_labels)=mnist.load_data()

network=models.Sequential() 
#two layer
network.add(layers.Dense(512,activation='relu',input_shape=(28*28,)))
network.add(layers.Dense(10,activation='softmax'))
#categorical_crossentropy is loss function that give feedback signal for weight tensor
network.compile(optimizer='rmsprop',loss='categorical_crossentropy',metrics=['accuracy'])
#data scalling
print(train_images[21].shape)  #train_images contain the values between 0 to 255 
plt.imshow(train_images[12324])
plt.show()
train_images=train_images.reshape((60000,28*28))
train_images=train_images.astype('float32')/255

test_images=test_images.reshape((10000,28*28))
test_images=test_images.astype('float32')/255

train_labels=to_categorical(train_labels)
test_labels=to_categorical(test_labels)

#each iteration over all the training data is called an epoch
network.fit(train_images,train_labels,epochs=5,batch_size=128)

#test_loss,test_acc=network.evaluate(test_images,test_labels)
#train_loss,train_acc=network.evaluate(train_images,train_labels) again fit on train datasets give more accuracy
print(test_acc)
print(test_loss)
# Out:
# (28, 28)
# WARNING:tensorflow:From C:\Users\ASUS\anaconda3\lib\site-packages\keras\backend\tensorflow_backend.py:422: The name tf.global_variables is deprecated. Please use tf.compat.v1.global_variables instead.
#
# Epoch 1/5
# 60000/60000 [==============================] - 9s 150us/step - loss: 0.2576 - accuracy: 0.9255
# Epoch 2/5
# 60000/60000 [==============================] - 9s 146us/step - loss: 0.1025 - accuracy: 0.9695
# Epoch 3/5
# 60000/60000 [==============================] - 9s 146us/step - loss: 0.0668 - accuracy: 0.98030s - loss: 0.0665 - accuracy: 0.
# Epoch 4/5
# 37248/60000 [=================>............] - ETA: 3s - loss: 0.0481 - accuracy: 0.9858
